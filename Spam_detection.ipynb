# %%
#!pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.7)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk) (4.64.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk) (2022.6.2)

# %% [markdown]
# Cleaning > stop word removal > lemmatization >Numeric representation ( TF-IDF vs word embeddding)

# %%
import nltk

nltk.download('stopwords')
nltk.download('punkt')

from nltk.corpus import stopwords

nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %% [markdown]
# ### 5.2. Creating Text Representations
#
# Text data needs to be converted to numeric representations before they can be used to train deep learning models. The Spam classification feature data is converted to TF-IDF vectors and the target variable is converted to one-hot encoding.

# %%
import pandas as pd
import os
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale

#Load Spam Data and review content
spam_data = pd.read_csv("/content/drive/MyDrive/Deep Learning /Exercise Files/Spam-Classification.csv")

print("\nLoaded Data :\n------------------------------------")
print(spam_data.head())

#Separate feature and target data
spam_classes_raw = spam_data["CLASS"]
spam_messages = spam_data["SMS"]
# Out:
# Loaded Data :
# ------------------------------------
#   CLASS                                                SMS
# 0   ham   said kiss, kiss, i can't do the sound effects...
# 1   ham      &lt;#&gt; ISH MINUTES WAS 5 MINUTES AGO. WTF.
# 2  spam  (Bank of Granite issues Strong-Buy) EXPLOSIVE ...
# 3  spam  * FREE* POLYPHONIC RINGTONE Text SUPER to 8713...
# 4  spam  **FREE MESSAGE**Thanks for using the Auction S...

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
import nltk
import tensorflow as tf
#nltk.download('omw-1.4')
#Custom tokenizer to remove stopwords and use lemmatization
def customtokenize(str):
    #Split string as tokens
    tokens=nltk.word_tokenize(str)
    #Filter for stopwords
    nostop = list(filter(lambda token: token not in stopwords.words('english'), tokens))
    #Perform lemmatization
    lemmatized=[lemmatizer.lemmatize(word) for word in nostop ]
    return lemmatized

from sklearn.feature_extraction.text import TfidfVectorizer

#Build a TF-IDF Vectorizer model
vectorizer = TfidfVectorizer(tokenizer=customtokenize)

#Transform feature input to TF-IDF
tfidf=vectorizer.fit_transform(spam_messages)
#Convert TF-IDF to numpy array
tfidf_array = tfidf.toarray()

#Build a label encoder for target variable to convert strings to numeric values.
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
spam_classes = label_encoder.fit_transform(
                                spam_classes_raw)

#Convert target to one-hot encoding vector
spam_classes = tf.keras.utils.to_categorical(spam_classes,2)

print("TF-IDF Matrix Shape : ", tfidf.shape)
print("One-hot Encoding Shape : ", spam_classes.shape)

X_train,X_test,Y_train,Y_test = train_test_split( tfidf_array, spam_classes, test_size=0.10)
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# TF-IDF Matrix Shape :  (1500, 4569)
# One-hot Encoding Shape :  (1500, 2)

# %% [markdown]
# ### 5.3. Building and Evaluating the Model

# %%
#creating the model
from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.regularizers import l2

#Setup Hyper Parameters for building the model
NB_CLASSES=2
N_HIDDEN=32

model = tf.keras.models.Sequential()

model.add(keras.layers.Dense(N_HIDDEN,
                             input_shape=(X_train.shape[1],),
                              name='Hidden-Layer-1',
                              activation='relu'))

model.add(keras.layers.Dense(N_HIDDEN,
                              name='Hidden-Layer-2',
                              activation='relu'))

model.add(keras.layers.Dense(NB_CLASSES,
                             name='Output-Layer',
                             activation='softmax'))

model.compile(loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Hidden-Layer-1 (Dense)      (None, 32)                146240
#
#  Hidden-Layer-2 (Dense)      (None, 32)                1056
#
#  Output-Layer (Dense)        (None, 2)                 66
#
# =================================================================
# Total params: 147,362
# Trainable params: 147,362
# Non-trainable params: 0
# _________________________________________________________________

# %%
# perform training 

#Make it verbose so we can see the progress
VERBOSE=1

#Setup Hyper Parameters for training
BATCH_SIZE=256
EPOCHS=10
VALIDATION_SPLIT=0.2

print("\nTraining Progress:\n------------------------------------")

history=model.fit(X_train,
          Y_train,
          batch_size=BATCH_SIZE,
          epochs=EPOCHS,
          verbose=VERBOSE,
          validation_split=VALIDATION_SPLIT)

print("\nAccuracy during Training :\n------------------------------------")
import matplotlib.pyplot as plt

pd.DataFrame(history.history)["accuracy"].plot(figsize=(8, 5))
plt.title("Accuracy improvements with Epoch")
plt.show()

print("\nEvaluation against Test Dataset :\n------------------------------------")
model.evaluate(X_test,Y_test)
# Out:
# Training Progress:
# ------------------------------------
# Epoch 1/10
# 5/5 [==============================] - 4s 353ms/step - loss: 0.6873 - accuracy: 0.6676 - val_loss: 0.6679 - val_accuracy: 0.9111
# Epoch 2/10
# 5/5 [==============================] - 0s 50ms/step - loss: 0.6459 - accuracy: 0.9602 - val_loss: 0.6231 - val_accuracy: 0.9519
# Epoch 3/10
# 5/5 [==============================] - 0s 63ms/step - loss: 0.5887 - accuracy: 0.9722 - val_loss: 0.5756 - val_accuracy: 0.9667
# Epoch 4/10
# 5/5 [==============================] - 0s 45ms/step - loss: 0.5289 - accuracy: 0.9852 - val_loss: 0.5264 - val_accuracy: 0.9667
# Epoch 5/10
# 5/5 [==============================] - 0s 44ms/step - loss: 0.4692 - accuracy: 0.9833 - val_loss: 0.4772 - val_accuracy: 0.9667
# Epoch 6/10
# 5/5 [==============================] - 0s 57ms/step - loss: 0.4107 - accuracy: 0.9833 - val_loss: 0.4301 - val_accuracy: 0.9778
# Epoch 7/10
# 5/5 [==============================] - 0s 58ms/step - loss: 0.3558 - accuracy: 0.9843 - val_loss: 0.3876 - val_accuracy: 0.9741
# Epoch 8/10
# 5/5 [==============================] - 0s 57ms/step - loss: 0.3056 - accuracy: 0.9861 - val_loss: 0.3465 - val_accuracy: 0.9741
# Epoch 9/10
# 5/5 [==============================] - 0s 52ms/step - loss: 0.2596 - accuracy: 0.9880 - val_loss: 0.3095 - val_accuracy: 0.9741
# Epoch 10/10
# 5/5 [==============================] - 0s 59ms/step - loss: 0.2192 - accuracy: 0.9898 - val_loss: 0.2796 - val_accuracy: 0.9630
#
# Accuracy during Training :
# ------------------------------------
# Evaluation against Test Dataset :
# ------------------------------------
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3239 - accuracy: 0.9333
# [0.323935329914093, 0.9333333373069763]

# %% [markdown]
# ### 5.4. Predicting for Text

# %%
#Predict for multiple samples using batch processing

#Convert input into IF-IDF vector using the same vectorizer model
predict_tfidf=vectorizer.transform(["FREE entry to a fun contest",
                                    "Yup I will come over"]).toarray()

print(predict_tfidf.shape)
# Out:
# (2, 4569)

# %%
#Predict using model
prediction=np.argmax( model.predict(predict_tfidf), axis=1 )
print("Prediction Output:" , prediction)

#Print prediction classes
print("Prediction Classes are ", label_encoder.inverse_transform(prediction))
# Out:
# 1/1 [==============================] - 0s 171ms/step
# Prediction Output: [1 0]
# Prediction Classes are  ['spam' 'ham']
